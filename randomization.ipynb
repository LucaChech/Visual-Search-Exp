# %%
import pandas as pd
import numpy as np
import random
import csv
df = pd.DataFrame.from_csv('C:/Users/luca.chech.16/Desktop/jupyter exp/all_images.csv')
#f = pd.DataFrame.from_csv('C:/Users/nilli lab/Desktop/Luca Exp/jupyter exp/all_images.csv')
df.reset_index(drop=False)

image_names = df.index.tolist()
cat1 = df['0'].tolist()
cat2 = df['1'].tolist()
cat3 = df['2'].tolist()
cat4 = df['3'].tolist()
cat5 = df['4'].tolist()
ts = df['5'].tolist()
load = df['6'].tolist()
possible_images_dict ={z[0]:list(z[1:]) for z in zip(image_names,cat1,cat2,cat3,cat4,cat5,ts,load)}

# DEFINING TARGET-PRESENT TRIALS
lista= possible_images_dict.keys()
target_present = []
intermediate = []
categories = [' bottle', ' horse', ' pottedplant', ' dog', ' cat', ' person', ' aeroplane', ' car', ' chair', ' sofa', ' bird', ' boat']
p_load = ['low','high']

for each_1 in categories:
    for load in p_load:
        i = 0
        while True:
            trial = np.random.choice(lista, 1, replace= False)
            a = str(trial)
            a =a[2:-2]
            if each_1 in possible_images_dict[a] and load in possible_images_dict[a] and a not in intermediate and a not in target_present:
                intermediate.append(a)
            if len(intermediate) == 10:
                for each in intermediate:
                    target_present.append(each)
                    possible_images_dict[each].append(each_1)
                intermediate = []
                break

print len(target_present)
#--------------------
target_present_dict = {key:possible_images_dict[key] for key in target_present}
target_absent_dict = dict(possible_images_dict)
for each in target_present:
    if each in target_absent_dict:
        del target_absent_dict[each]
exp_dict = dict(target_present_dict)
exp_dict.update(target_absent_dict)
print len(target_present_dict)
print len(target_absent_dict)
print len(exp_dict)


for each in target_present_dict:
    target_present_dict[each].append('Target Present')
for each in target_absent_dict:
    absent_question = []
    for ogni in categories:
        if ogni not in target_absent_dict[each]:
            absent_question.append(ogni)
    absent_question = np.random.choice(absent_question, 1, replace= False)
    absent_question = str(absent_question)
    absent_question = absent_question[2:-2]
    #print absent_question
    #print type(absent_question)
    target_absent_dict[each].append(absent_question)
    target_absent_dict[each].append('Target Absent')
    
# DEFINING CRITICAL TRIALS
critical_trials = []
def critical_trial(load_level, present_absent):
    intermediate = []
    for element in lista:
        if load_level in possible_images_dict[element] and present_absent in possible_images_dict[element]:
            intermediate.append(element)  
    intermediate = np.random.choice(intermediate, 20, replace= False)
    for each in intermediate:
        each = str(each)
        critical_trials.append(each)
critical_trial('low','Target Present')
critical_trial('high','Target Present')
critical_trial('low','Target Absent')
critical_trial('high','Target Absent')

for each in critical_trials:
    exp_dict[each].append('Critical')
for each in exp_dict:
    if 'Critical' not in exp_dict[each]:
        exp_dict[each].append('Normal')
#-----------------------

df = pd.DataFrame.from_dict(exp_dict)
df= df.T
#df.reset_index(inplace = 'True')
df.columns = ['Cat.1','Cat.2','Cat.3','Cat.4','Cat.5','TS','Load','question','present_absent','trial_type']
df.TS = df.TS.astype('float')

df.to_csv('randomization.csv')
#df.groupby(['trial_type','present_absent', 'Load']).TS.count()
#df.groupby(['trial_type', 'Load']).TS.count()
df.groupby(['trial_type', 'Load']).TS.mean()
df
# Out:
# 240
# 240
# 240
# 480
#                         Cat.1         Cat.2         Cat.3       Cat.4  \
# 2008_000015.jpg        bottle           NaN           NaN         NaN
# 2008_000023.jpg     tvmonitor        bottle        person         NaN
# 2008_000033.jpg     aeroplane           NaN           NaN         NaN
# 2008_000036.jpg        person       bicycle          boat         NaN
# 2008_000037.jpg     aeroplane           NaN           NaN         NaN
# 2008_000064.jpg     aeroplane           NaN           NaN         NaN
# 2008_000076.jpg         horse           NaN           NaN         NaN
# 2008_000089.jpg         chair           NaN           NaN         NaN
# 2008_000112.jpg        bottle           cat           NaN         NaN
# 2008_000142.jpg        person         horse           NaN         NaN
# 2008_000177.jpg         horse           NaN           NaN         NaN
# 2008_000185.jpg        person           car           NaN         NaN
# 2008_000189.jpg        person           car           NaN         NaN
# 2008_000192.jpg          bird           NaN           NaN         NaN
# 2008_000196.jpg   pottedplant       bicycle        bottle         cat
# 2008_000202.jpg        person         chair        bottle   tvmonitor
# 2008_000226.jpg        person           car           NaN         NaN
# 2008_000251.jpg           car     aeroplane           NaN         NaN
# 2008_000270.jpg        person           dog          sofa         NaN
# 2008_000274.jpg   pottedplant         chair           NaN         NaN
# 2008_000287.jpg   pottedplant           NaN           NaN         NaN
# 2008_000359.jpg        person           NaN           NaN         NaN
# 2008_000398.jpg        person        bottle           NaN         NaN
# 2008_000399.jpg           car           NaN           NaN         NaN
# 2008_000421.jpg        person        bottle          sofa         NaN
# 2008_000501.jpg           car           NaN           NaN         NaN
# 2008_000533.jpg          bird           NaN           NaN         NaN
# 2008_000536.jpg           cat           NaN           NaN         NaN
# 2008_000564.jpg   pottedplant        person           NaN         NaN
# 2008_000619.jpg           car           cat           NaN         NaN
# ...                       ...           ...           ...         ...
# 2011_001566.jpg   pottedplant         chair       bicycle         NaN
# 2011_001591.jpg        person          boat           NaN         NaN
# 2011_001605.jpg   pottedplant        person     motorbike         NaN
# 2011_001613.jpg        person          boat           NaN         NaN
# 2011_001655.jpg        person         train           NaN         NaN
# 2011_001656.jpg         horse           NaN           NaN         NaN
# 2011_001779.jpg          bird           NaN           NaN         NaN
# 2011_001800.jpg        person     aeroplane           NaN         NaN
# 2011_001862.jpg   pottedplant          sofa         chair         dog
# 2011_001880.jpg     aeroplane           NaN           NaN         NaN
# 2011_001886.jpg          boat           NaN           NaN         NaN
# 2011_001902.jpg          bird           NaN           NaN         NaN
# 2011_001930.jpg         chair           NaN           NaN         NaN
# 2011_001972.jpg         chair           NaN           NaN         NaN
# 2011_001991.jpg          boat           NaN           NaN         NaN
# 2011_002050.jpg          boat           NaN           NaN         NaN
# 2011_002098.jpg           dog        bottle           NaN         NaN
# 2011_002193.jpg        person     aeroplane           NaN         NaN
# 2011_002239.jpg        person           dog           NaN         NaN
# 2011_002241.jpg         chair   diningtable           NaN         NaN
# 2011_002453.jpg   pottedplant           NaN           NaN         NaN
# 2011_002558.jpg        person          boat           NaN         NaN
# 2011_002624.jpg        person           NaN           NaN         NaN
# 2011_002631.jpg           cat           NaN           NaN         NaN
# 2011_002760.jpg        person     motorbike           NaN         NaN
# 2011_002766.jpg          sofa           dog           NaN         NaN
# 2011_002810.jpg   pottedplant     tvmonitor         chair        sofa
# 2011_002814.jpg          sofa        bottle   pottedplant   tvmonitor
# 2011_003098.jpg           dog           NaN           NaN         NaN
# 2011_003244.jpg         horse           NaN           NaN         NaN
#
#                         Cat.5         TS  Load      question  present_absent  \
# 2008_000015.jpg           NaN  31.539720  high   pottedplant   Target Absent
# 2008_000023.jpg           NaN  35.932514  high         horse   Target Absent
# 2008_000033.jpg           NaN  16.997423   low         chair   Target Absent
# 2008_000036.jpg           NaN  33.118834  high           car   Target Absent
# 2008_000037.jpg           NaN  12.091823   low     aeroplane  Target Present
# 2008_000064.jpg           NaN  18.799444   low        bottle   Target Absent
# 2008_000076.jpg           NaN  20.993717   low         chair   Target Absent
# 2008_000089.jpg           NaN  14.267558   low           dog   Target Absent
# 2008_000112.jpg           NaN  21.259830   low        bottle  Target Present
# 2008_000142.jpg           NaN  19.226645   low         chair   Target Absent
# 2008_000177.jpg           NaN  16.396956   low         chair   Target Absent
# 2008_000185.jpg           NaN  17.007638   low         horse   Target Absent
# 2008_000189.jpg           NaN  18.390878   low           car  Target Present
# 2008_000192.jpg           NaN  29.176311  high        bottle   Target Absent
# 2008_000196.jpg           NaN  35.353784  high        bottle  Target Present
# 2008_000202.jpg           NaN  34.633056  high         horse   Target Absent
# 2008_000226.jpg           NaN  38.328936  high           car  Target Present
# 2008_000251.jpg           NaN  35.872179  high         horse   Target Absent
# 2008_000270.jpg           NaN  29.935618  high   pottedplant   Target Absent
# 2008_000274.jpg           NaN  32.054270  high     aeroplane   Target Absent
# 2008_000287.jpg           NaN  19.549656   low   pottedplant  Target Present
# 2008_000359.jpg           NaN  29.574954  high     aeroplane   Target Absent
# 2008_000398.jpg           NaN  20.423795   low   pottedplant   Target Absent
# 2008_000399.jpg           NaN  20.515949   low           car  Target Present
# 2008_000421.jpg           NaN  28.876320  high        bottle  Target Present
# 2008_000501.jpg           NaN  18.298678   low         horse   Target Absent
# 2008_000533.jpg           NaN  13.809457   low          bird  Target Present
# 2008_000536.jpg           NaN  16.530475   low        bottle   Target Absent
# 2008_000564.jpg           NaN  31.190713  high           dog   Target Absent
# 2008_000619.jpg           NaN  33.462185  high         horse   Target Absent
# ...                       ...        ...   ...           ...             ...
# 2011_001566.jpg           NaN  34.252594  high   pottedplant  Target Present
# 2011_001591.jpg           NaN  17.698167   low        person  Target Present
# 2011_001605.jpg           NaN  34.416005  high   pottedplant  Target Present
# 2011_001613.jpg           NaN  17.516941   low   pottedplant   Target Absent
# 2011_001655.jpg           NaN  33.249285  high           dog   Target Absent
# 2011_001656.jpg           NaN  19.156547   low         horse  Target Present
# 2011_001779.jpg           NaN  18.684731   low     aeroplane   Target Absent
# 2011_001800.jpg           NaN  30.953043  high        bottle   Target Absent
# 2011_001862.jpg   diningtable  32.892562  high         chair  Target Present
# 2011_001880.jpg           NaN  32.202764  high     aeroplane  Target Present
# 2011_001886.jpg           NaN  19.685752   low          boat  Target Present
# 2011_001902.jpg           NaN  19.504215   low          bird  Target Present
# 2011_001930.jpg           NaN  18.813367   low         chair  Target Present
# 2011_001972.jpg           NaN  10.593867   low         chair  Target Present
# 2011_001991.jpg           NaN  34.047147  high          boat  Target Present
# 2011_002050.jpg           NaN  17.331558   low        bottle   Target Absent
# 2011_002098.jpg           NaN  41.997145  high          boat   Target Absent
# 2011_002193.jpg           NaN  30.182886  high     aeroplane  Target Present
# 2011_002239.jpg           NaN  31.319653  high           dog  Target Present
# 2011_002241.jpg           NaN  18.117803   low          boat   Target Absent
# 2011_002453.jpg           NaN  19.249761   low        person   Target Absent
# 2011_002558.jpg           NaN  16.146155   low          boat  Target Present
# 2011_002624.jpg           NaN  31.033903  high        person  Target Present
# 2011_002631.jpg           NaN  29.376810  high           car   Target Absent
# 2011_002760.jpg           NaN  29.237451  high          sofa   Target Absent
# 2011_002766.jpg           NaN  19.885627   low           dog  Target Present
# 2011_002810.jpg           NaN  35.636604  high        person   Target Absent
# 2011_002814.jpg         chair  33.937776  high   pottedplant  Target Present
# 2011_003098.jpg           NaN  14.526602   low           dog  Target Present
# 2011_003244.jpg           NaN  14.779477   low         horse  Target Present
#
#                 trial_type
# 2008_000015.jpg   Critical
# 2008_000023.jpg     Normal
# 2008_000033.jpg   Critical
# 2008_000036.jpg     Normal
# 2008_000037.jpg     Normal
# 2008_000064.jpg     Normal
# 2008_000076.jpg     Normal
# 2008_000089.jpg   Critical
# 2008_000112.jpg     Normal
# 2008_000142.jpg     Normal
# 2008_000177.jpg     Normal
# 2008_000185.jpg     Normal
# 2008_000189.jpg     Normal
# 2008_000192.jpg     Normal
# 2008_000196.jpg     Normal
# 2008_000202.jpg     Normal
# 2008_000226.jpg     Normal
# 2008_000251.jpg     Normal
# 2008_000270.jpg     Normal
# 2008_000274.jpg     Normal
# 2008_000287.jpg     Normal
# 2008_000359.jpg   Critical
# 2008_000398.jpg     Normal
# 2008_000399.jpg     Normal
# 2008_000421.jpg     Normal
# 2008_000501.jpg     Normal
# 2008_000533.jpg     Normal
# 2008_000536.jpg     Normal
# 2008_000564.jpg     Normal
# 2008_000619.jpg     Normal
# ...                    ...
# 2011_001566.jpg     Normal
# 2011_001591.jpg   Critical
# 2011_001605.jpg   Critical
# 2011_001613.jpg     Normal
# 2011_001655.jpg   Critical
# 2011_001656.jpg   Critical
# 2011_001779.jpg     Normal
# 2011_001800.jpg     Normal
# 2011_001862.jpg     Normal
# 2011_001880.jpg   Critical
# 2011_001886.jpg     Normal
# 2011_001902.jpg   Critical
# 2011_001930.jpg     Normal
# 2011_001972.jpg     Normal
# 2011_001991.jpg     Normal
# 2011_002050.jpg     Normal
# 2011_002098.jpg   Critical
# 2011_002193.jpg     Normal
# 2011_002239.jpg   Critical
# 2011_002241.jpg     Normal
# 2011_002453.jpg   Critical
# 2011_002558.jpg     Normal
# 2011_002624.jpg     Normal
# 2011_002631.jpg     Normal
# 2011_002760.jpg     Normal
# 2011_002766.jpg     Normal
# 2011_002810.jpg     Normal
# 2011_002814.jpg     Normal
# 2011_003098.jpg     Normal
# 2011_003244.jpg   Critical
#
# [480 rows x 10 columns]
